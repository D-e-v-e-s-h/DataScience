# %%
from autogen_ext.models.openai import OpenAIChatCompletionClient
from dotenv import load_dotenv
import os
print(os.getenv("OPENAI_API_KEY"))
# Out:
# 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

# %%
def find_duplicates(arr):
    seen = set()
    duplicates = set()

    for num in arr:
        if num in seen:
            duplicates.add(num)
        else:
            seen.add(num)

    return list(duplicates)
arrr = [float(x) for x in input().split(",")]
print(find_duplicates(arrr))

# %%
a = list(map(int, input("Enter numbers:").split()))
print(a)
# Out:
# [1, 2, 3, 4, 5]
